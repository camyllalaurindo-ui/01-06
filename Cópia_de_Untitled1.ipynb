# %% [markdown]
# <a href="https://colab.research.google.com/github/camyllalaurindo-ui/01-06/blob/main/C%C3%B3pia_de_Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
alfabeto = "abcdefghijklmnopqrstuvwxyz"
senha = "marcelo"
senha_criptografada = ""

dicionario = "qwertyuiopasdfghjklzxcvbnm"

for letra in senha:
    posicao = ord(letra) - ord("a")
    senha_criptografada += dicionario[posicao]

print(senha_criptografada)
# Out:
# dqketsg
